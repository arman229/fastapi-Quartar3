# %%
# Python program to illustrate functions 
# can be treated as objects 
def shout(text): 
	return text.upper() 

print(shout('Hello')) 

yell = shout 

print(yell('Hello'))
# Out:
# HELLO
# HELLO

# %%
from jose import jwt, JWTError
ALGORITHM = 'HS256'
SECRET_KEY = 'XCSDFPOPPDsfpadsD783440'
token="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MTYzMzE5OTIsInN1YiI6InVzbWFuQGdtYWlsLmNvbSIsIm5hbWUiOiJNdWhhbW1hZCBVc21hbiJ9.m6Kvzuc5tkaIgb4urQKdldo_bBMNKAFHuPdefR3pOhg"
payload = jwt.decode(token, str(SECRET_KEY), [str(ALGORITHM)])
expiration = payload.get("exp")
print(f"expiration: {expiration}")

# %%
 
def hello_decorator(func): 
	def inner1():
		print("Hello, this is before function execution") 
		func() 
		print("This is after function execution") 
	return inner1 
def function_to_be_used():
	print("This is inside the function !!")  
function_to_be_used = hello_decorator(function_to_be_used) 
function_to_be_used()
# Out:
# Hello, this is before function execution
# This is inside the function !!
# This is after function execution

# %%
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()
# Out:
# Running cells with 'backend-authportal-maXUlxd8-py3.12 (Python 3.12.1)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/HP/AppData/Local/pypoetry/Cache/virtualenvs/backend-authportal-maXUlxd8-py3.12/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# !pip install moviepy
# Out:
# ...
#      ---------------------------------------- 0.0/388.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/388.3 kB ? eta -:--:--
#      - ----------------------------------- 20.5/388.3 kB 165.2 kB/s eta 0:00:03
#      - ----------------------------------- 20.5/388.3 kB 165.2 kB/s eta 0:00:03
#      --- --------------------------------- 41.0/388.3 kB 178.6 kB/s eta 0:00:02
#      ---- -------------------------------- 51.2/388.3 kB 201.8 kB/s eta 0:00:02
#      ----- ------------------------------- 61.4/388.3 kB 218.8 kB/s eta 0:00:02
#      ------ ------------------------------ 71.7/388.3 kB 218.6 kB/s eta 0:00:02
#      -------- ---------------------------- 92.2/388.3 kB 262.6 kB/s eta 0:00:02
#      ------------- ---------------------- 143.4/388.3 kB 355.0 kB/s eta 0:00:01
#      -------------- --------------------- 153.6/388.3 kB 367.6 kB/s eta 0:00:01
#      -------------- --------------------- 153.6/388.3 kB 367.6 kB/s eta 0:00:01
# ...

# %%
from moviepy.editor import ImageClip, concatenate_videoclips
import requests
from io import BytesIO
from PIL import Image
import numpy as np

# Example URLs for demonstration
image_urls = [
       "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-tPeSVSiZxfx3SP3p5L2eqxXNKD6ddAlqUHVEhBzjAwutC-gKqzyhM95r-XE&s=10",

    "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT-tPeSVSiZxfx3SP3p5L2eqxXNKD6ddAlqUHVEhBzjAwutC-gKqzyhM95r-XE&s=10",
]

# Download images and create ImageClip objects
image_clips = []
for url in image_urls:
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))  # Open image using PIL
    img_array = np.array(img)  # Convert PIL image to numpy array
    img_clip = ImageClip(img_array).set_duration(2)  # Create ImageClip from numpy array
    image_clips.append(img_clip)

# Check if image_clips list is not empty
if image_clips:
    # Concatenate image clips into final video clip
    final_clip = concatenate_videoclips(image_clips, method="compose")
    
    if final_clip:
        # Write final video file
        final_clip.write_videofile("final_video.mp4", fps=24)
    else:
        print("Error: Concatenation of image clips failed.")
else:
    print("Error: No image clips found to concatenate.")
# Out:
# Moviepy - Building video final_video.mp4.
# Moviepy - Writing video final_video.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 30
#      26 final_clip = concatenate_videoclips(image_clips, method="compose")
#      28 if final_clip:
#      29     # Write final video file
# ---> 30     final_clip.write_videofile("final_video.mp4", fps=24)
#      31 else:
#      32     print("Error: Concatenation of image clips failed.")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\decorator.py:232, in fun(*args, **kw)
#
# File c:\Users\arman\AppData\Local\Programs\Python\Python312\Lib\site-packages\moviepy\decorators.py:54, in requires_duration(f, clip, *a, **k)
#      52     raise ValueError("Attribute 'duration' not set")
#      53 else:
# ---> 54     return f(clip, *a, **k)
#
# ...
